# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
nofts=10000

t=linspace(-20*2*pi, 20*2*pi, nofts)

tau1=2*2*pi
tau2=2*2*pi
delay=9*2*pi
y= sin(t)*exp(-t**2/2/tau1**2)

y=y+sin(5*t)*exp(-(t-delay)**2/2/tau2**2)

# %%
plot(t/2/pi,y)

# %%
sp=fft.fft(y)
w=fft.fftfreq(len(y), d = t[1]-t[0])

plot(w*2*pi, abs(sp))
xlim(0,7)
# Out:
# (0, 7)

# %%
plot(y)
wlength=1*2*pi

nofts_win=100

poss=linspace(-20*2*pi, 20*2*pi, nofts_win)

specgram = np.zeros([nofts,nofts_win])


for n,pos in enumerate(poss):
    window=exp(-(t-pos)**16/wlength**16)
    #plot(y*window)
    sp=fft.fft(y*window)
    specgram[:,n]=abs(sp)

# %%
dw=1./(t[1]-t[0])/nofts

imshow(sqrt(specgram), aspect='auto', origin='lower', extent=[-20,20,0,nofts*dw*2*pi])
ylim(0,10)
ylabel(r'$\omega$', fontsize=16)
xlabel('t', fontsize=16)
# Out:
# Text(0.5, 0, 't')

# %%
import pywt
import pywt.data

# %%
# Load image
original = pywt.data.camera()

# Wavelet transform of image, and plot approximation and details
titles = ['Approximation', ' Horizontal detail',
          'Vertical detail', 'Diagonal detail']

coeffs2 = pywt.dwt2(original, 'bior1.3')
LL, (LH, HL, HH) = coeffs2
fig = plt.figure(figsize=(12, 3))

for i, a in enumerate([LL, LH, HL, HH]):
    ax = fig.add_subplot(1, 4, i + 1)
    ax.imshow(a, interpolation="nearest", cmap=plt.cm.gray)
    ax.set_title(titles[i], fontsize=10)
    ax.set_xticks([])
    ax.set_yticks([])

fig.tight_layout()
plt.show()

# %%
import pywt
import pywt.data
